# %%
import numpy as np
import seaborn as sns

# %%
# %matplotlib inline

# %%
filenames = ['data/2017-05-22-measurements-phenotype_evaluation/single_objective/HvsL.txt',
             'data/2017-05-22-measurements-phenotype_evaluation/single_objective/HvsRand.txt',
             'data/2017-05-22-measurements-phenotype_evaluation/single_objective/MvsL.txt',
             'data/2017-05-22-measurements-phenotype_evaluation/single_objective/MvsRand.txt',
             'data/2017-05-22-measurements-phenotype_evaluation/single_objective/Nearestpill2VSLegacy_clean.txt',
             'data/2017-05-22-measurements-phenotype_evaluation/single_objective/Nearestpill2VSRandom_clean.txt',
             'data/2017-05-22-measurements-phenotype_evaluation/single_objective/NearestpillVSLegacy.txt',
             'data/2017-05-22-measurements-phenotype_evaluation/single_objective/NearestpillVSLegacy_new.txt',
             'data/2017-05-22-measurements-phenotype_evaluation/single_objective/NearestpillVSRand.txt',
             'data/2017-05-22-measurements-phenotype_evaluation/single_objective/NearestpillVSRand_new.txt',
             'data/2017-05-22-measurements-phenotype_evaluation/single_objective/RandnorevVSLegacy.txt',
             'data/2017-05-22-measurements-phenotype_evaluation/single_objective/RandnorevVSRand.txt',
             'data/2017-05-22-measurements-phenotype_evaluation/single_objective/RandVSLegacy.txt',
             'data/2017-05-22-measurements-phenotype_evaluation/single_objective/RandVSRand.txt']

# %%
def study(filename):
    with open(filename) as f:
        score = f.readline()
        last_level = f.readline()[:-1]
        time = f.readline()[:-1]
    
    score = np.array([int(b) for b in list(score.split(','))[:-1]])
    last_level = np.array([int(b) for b in list(last_level.split(','))[:-1]])
    time = np.array([int(b) for b in list(time.split(','))[:-1]])

    print(filename)
    print('score')
    print('  mean: ' + str(score.mean()))
    print('  best: ' + str(score.max()))
    print('  std: ' + str(score.std()))
    print('last_level')
    print('  mean: ' + str(last_level.mean()))
    print('  best: ' + str(last_level.max()))
    print('  std: ' + str(last_level.std()))
    print('time')
    print('  mean: ' + str(time.mean()))
    print('  best: ' + str(time.max()))
    print('  std: ' + str(time.std()))
    print()

# %%
[study(filename) for filename in filenames];
# Out:
# data/2017-05-22-measurements-phenotype_evaluation/single_objective/HvsL.txt
# score
#   mean: 5971.89
#   best: 20040
#   std: 2832.07601026
# last_level
#   mean: 1.032
#   best: 4
#   std: 0.644186308454
# time
#   mean: 2025.94
#   best: 8364
#   std: 1019.82808081
#
# data/2017-05-22-measurements-phenotype_evaluation/single_objective/HvsRand.txt
# score
#   mean: 32704.37
#   best: 55480
#   std: 13236.9868325
# last_level
#   mean: 10.392
#   best: 18
#   std: 4.30375835753
# time
#   mean: 17456.955
#   best: 24000
#   std: 6784.33343955
#
# data/2017-05-22-measurements-phenotype_evaluation/single_objective/MvsL.txt
# score
#   mean: 6358.26
#   best: 15960
#   std: 2883.33244223
# last_level
#   mean: 0.889
#   best: 3
#   std: 0.700484832098
# time
#   mean: 1915.745
#   best: 4973
#   std: 729.882509706
#
# data/2017-05-22-measurements-phenotype_evaluation/single_objective/MvsRand.txt
# score
#   mean: 48557.84
#   best: 64600
#   std: 10780.296709
# last_level
# ...
